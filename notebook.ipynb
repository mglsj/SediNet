# %%
# !CONFIG=config/config_9percentiles.json

# %% [markdown]
# Train Model with 9 Percentile Features

# %%
# !python sedinet_train.py -c $CONFIG

# %%
# !WEIGHTS_DIR=grain_size_global/

# %% [markdown]
# Test Model with 9 Percentile Features

# %%
# !python sedinet_train.py -c $CONFIG -w $WEIGHTS_DIR
