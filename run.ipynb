# %% [markdown]
# Train Model with 9 Percentile Features
#
# ```bash
# python sedinet_train.py -c config/config_9percentiles.json
# ```

# %%
# !python sedinet_train.py -c config/config_9percentiles.json
